# %%
import requests
import pandas as pd
import numpy as np

# %%
req_starwar=requests.get('https://swapi.dev/api/people/')

# %%
req_starwar.ok
# Out:
# True

# %%
req_starwar.text
# Out:
# '{"count":82,"next":"https://swapi.dev/api/people/?page=2","previous":null,"results":[{"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/14/","https://swapi.dev/api/vehicles/30/"],"starships":["https://swapi.dev/api/starships/12/","https://swapi.dev/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"https://swapi.dev/api/people/1/"},{"name":"C-3PO","height":"167","mass":"75","hair_color":"n/a","skin_color":"gold","eye_color":"yellow","birth_year":"112BBY","gender":"n/a","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","h
# ...

# %%
starwars_df=pd.read_json(req_starwar.text).head()
# Out:
# <ipython-input-14-a872885c3316>:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   starwars_df=pd.read_json(req_starwar.text).head()

# %%
starwars_dic=req_starwar.json()

# %%
starwars_dic
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
starwars_df=pd.DataFrame.from_dict(starwars_dic['results'])
starwars_df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                          homeworld  \
# 0      19BBY    male   https://swapi.dev/api/planets/1/
# ...

# %%
ojoazul_people_df=starwars_df.loc[starwars_df['eye_color']=='blue']
ojoazul_people_df
# Out:
#                  name height mass   hair_color skin_color eye_color  \
# 0      Luke Skywalker    172   77        blond       fair      blue
# 5           Owen Lars    178  120  brown, grey      light      blue
# 6  Beru Whitesun lars    165   75        brown      light      blue
#
#   birth_year  gender                         homeworld  \
# 0      19BBY    male  https://swapi.dev/api/planets/1/
# 5      52BBY    male  https://swapi.dev/api/planets/1/
# 6      47BBY  female  https://swapi.dev/api/planets/1/
#
#                                                films species  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...      []
# 5  [https://swapi.dev/api/films/1/, https://swapi...      []
# 6  [https://swapi.dev/api/films/1/, https://swapi...      []
#
#                                             vehicles  \
# 0  [https://swapi.dev/api/vehicles/14/, https://s...
# 5                                                 []
# 6                                                 []
#
# ...
